# %%
celsius = input("Digite a temperatura em Celsius:")
# Out:
# Digite a temperatura em Celsius: 28

# %%
celsius = float(celsius)
fahrenheit = (celsius*9/5) + 32
print(fahrenheit)
# Out:
# 82.4

# %%
n1 = float(input("Nota 1: \t"))
n2 = float(input("Nota 2: \t"))
n3 = float(input("Nota 3: \t"))
total = n1 + n2 + n3
# Out:
# Nota 1: 	 7
# Nota 2: 	 7
# Nota 3: 	 7

# %%
if (n1 + n2 + n3)/3 < 7:
    print("TÁ DE Reposição""")
    reposicao = float(input("Nota da reposição: \t"))
else:
    print("Aprovada")
# Out:
# Aprovada

# %%
media = total + reposicao - min ([n1, n2, n3, reposicao])/3
print("Média anterior:", total/3, "Menor nota:", min([n1,n2,n3]))
print("Média Final:", round(media, 1))
# Out:
# Média anterior: 2.0 Menor nota: 1.0
# Média Final: 10.7

# %%
distancia = float(input("Qual a distância em quilômetros da sua corrida? "))
tempo = float(input("Quantos minutos durará da sua corrida? "))
# Out:
# Qual a distância em quilômetros da sua corrida?  9.8
# Quantos minutos durará da sua corrida?  14

# %%
preco = 2.5*distancia + 0.5*tempo
print("A corrida custará: ", preco)
# Out:
# A corrida custará:  31.5
